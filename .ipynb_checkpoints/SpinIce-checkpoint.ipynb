# %% [markdown]
# # Frustration and Spin Ice
# ### Christina Lee
# ### Category: Prerequisites
# ### Prerequisites: Monte Carlo Ferromagnet, Phase Transitions, Statistical Mechanics
#
#         name::String
#         l::Int16
#         dim::Int8
#         a::Array
#         unit::Array
#         N::Int16
#         X::Array
#         nnei::Int8
#         neigh::Array
#
# $$
# d S= \frac{d Q}{T} \qquad d Q= C dT
# $$
#
# $$
# S(T) = S(\infty) + \int_{\infty}^{T} \frac{ C dT}{T}
# $$

# %% [markdown]
# Load our packages.
#
# `Lattices.jl` is the same class I used in the previous post.  Well, I got around to updating the Julia syntax.  So mostly the same.

# %%
push!(LOAD_PATH,".")
using Lattices;
using Statistics
using QuadGK
using DelimitedFiles
using Plots
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# Here we set up our lattice.

# %%
## Define l here
l=20;

lt=MakeLattice("Checkerboard",l);
S=ones(Int8,l,l);  #Our spins
dt=1/(lt.N);

# %%
l_view=6;

lt_view=MakeLattice("Checkerboard",l_view);

plot()

for ii in 1:lt_view.N
    for jj in 1:lt_view.nnei
        kk=lt_view.neigh[ii,jj]
        plot!([lt_view.X[ii,1],lt_view.X[kk,1]],[lt_view.X[ii,2],lt_view.X[kk,2]],
        linecolor=colorant"#6c71c4")
    end
    plot!(lt_view.X[ii,1].+0.25*[0,vs_view[ii][1]],
        lt_view.X[ii,2].+0.25*[0,vs_view[ii][2]],linewidth=5)
    end

scatter!(lt_view.X[:,1],lt_view.X[:,2],color=colorant"#dc322f")
scatter!([lt_view.X[2,1]],[lt_view.X[2,2]],markersize=5)
plot!(legend=:false,title="The Checkerboard Lattice",aspect_ratio=1)

# %%
vs_view=Array{Array}(undef,lt_view.N)

for ii in 1:lt_view.N
    if iseven(floor(Int,(ii-1)/lt_view.l))
        if isodd(ii)
            vs_view[ii]=v1
        else
            vs_view[ii]=v2
        end
    else
        if isodd(ii)
            vs_view[ii]=v3
        else
            vs_view[ii]=v4
        end
    end
end

vs=Array{Array}(undef,lt.N)
for ii in 1:lt.N
    if iseven(floor(Int,(ii-1)/lt.l))
        if isodd(ii)
            vs[ii]=v1
        else
            vs[ii]=v2
        end
    else
        if isodd(ii)
            vs[ii]=v3
        else
            vs[ii]=v4
        end
    end
end

# %%
v1=1/sqrt(2)*[1 , 1]
v2=1/sqrt(2)*[-1,1]
v3=1/sqrt(2)*[1,-1]
v4=1/sqrt(2)*[-1,-1]
# Out:
# 2-element Array{Float64,1}:
#  -0.7071067811865475
#  -0.7071067811865475

# %% [markdown]
# Same as last time.
#
# These functions calculate properties of our lattice.

# %%
# The energy contribution of just one site
function dE(i::Int)
    Eii=0;
    for j in 1:lt.nnei
        Eii+=S[lt.neigh[i,j]];
    end
    Eii*=-J*S[i];  # we are computing J sz_i sz_j for one i
    return Eii;
end
# The energy of the entire lattice
function E()
    Evar=0;
    for k in 1:lt.N
        Evar+=.5*dE(k);
    end
    return Evar;
end
# The magnetization of the entire lattice
function M()
    Mvar=0;
    for k in 1:lt.N
        Mvar+=S[k];
    end
    return Mvar;
end
function M2D()
    Mvar=[0.,0.];
    for k in 1:lt.N
        Mvar+=S[k]*vs[k];
    end
    return Mvar;
end
"defined functions"
# Out:
# "defined functions"

# %%
sum(M2D().^2)
# Out:
# 324.00000000000017

# %% [markdown]
# ### Adjustable Parameters

# %%
beta0=.025;
betaf=1;
dbeta=.025;

J=-1;
t=10000;
nskip=10;   # don't measure every sweep= better decorrelation
"Parameters set"
# Out:
# "Parameters set"

# %%
nmeas=Int64(t/nskip); # how many times we will measure
#betas=collect(beta0:dbeta:betaf)
betas=10.0 .^(collect(-3:.1:2))
"done"
# Out:
# "done"

# %% [markdown]
# I took what we ran last time and wrapped it into a function, `MCMCMagnet`.  We aren't looking at spin configurations this time; we only want the final measureables, which get returned at the end.

# %%
function MCMCMagnet(beta::Float64)
    tm=1; #Our measurement time step
    
    Ma=Array{Int32}(undef,nmeas); # our magnetization measurements
    Ea=Array{Int32}(undef,nmeas); # our energy measurements
    Ma2=Array{Int32}(undef,nmeas); # magnetization squared
    Ma_2D=Array{Float64}(undef,2,nmeas); 
    Ma2_2D=Array{Float64}(undef,2,nmeas); 
    Ea2=Array{Int32}(undef,nmeas); # energy squared
    
    for ti in 1:t
        for j in 1:lt.N
            i = rand(1:lt.N); #Choosing a random site
            de=dE(i);
            if(de>0 || rand()<exp(2*beta*de) ) 
                S[i]=-S[i]; #Switch the sign
            end
        end
        if isapprox(mod(ti,nskip),0)
            Ma[tm]=M()
            Ma2[tm]=Ma[tm]^2
            
            Ma_2D[:,tm]=M2D()
            Ma2_2D[:,tm]=Ma_2D[:,tm].^2
            
            Ea[tm]=E()
            Ea2[tm]=Ea[tm]^2
            
            tm+=1

        end
    end
    Mave=mean(Ma);
    Mstd=std(Ma)/lt.N;
    Eave=mean(Ea);
    Estd=std(Ea)/lt.N;
    
    E2ave=mean(Ea2);
    M2ave=mean(Ma2);
    
    M_2Dave=norm(sum(Ma_2D,2))
    M2_2Dave=norm(sum(Ma2_2D,2) )
    χ2D=beta*(M2_2Dave-M_2Dave*M_2Dave)
    
    Ch=beta^2*(E2ave-Eave^2)/lt.N;
    χ=beta*(M2ave-Mave^2)/lt.N;
    
    return Mave/lt.N,Mstd,Eave/lt.N,Estd,Ch,χ,χ2D
end
# Out:
# MCMCMagnet (generic function with 1 method)

# %% [markdown]
# # The Temperature Loop
#
# This cell looks pretty simple: initialization and one for loop.  But this is where everything ties together.

# %%
betas

# %%
Mm=zeros(length(betas))
Mstd=zeros(length(betas))
Ee=zeros(length(betas))
Estd=zeros(length(betas))
Ch=zeros(length(betas))
χ=zeros(length(betas))
χ2D=zeros(length(betas))
for ii in 1:length(betas)
    Mm[ii],Mstd[ii],Ee[ii],Estd[ii],Ch[ii],χ2D[ii]=MCMCMagnet(betas[ii])
    println("beta: ",betas[ii],"\tM: ",Mm[ii],"\tE: ",Ee[ii])
end
# Out:
# MethodError: objects of type Array{Float64,2} are not callable
# Use square brackets [] for indexing an Array.
#
# Stacktrace:
#  [1] mapreduce_first(::Array{Float64,2}, ::Function, ::Int64) at ./reduce.jl:295
#  [2] mapreduce(::Array{Float64,2}, ::Function, ::Int64) at ./reduce.jl:322
#  [3] sum(::Array{Float64,2}, ::Int64) at ./reduce.jl:397
#  [4] MCMCMagnet(::Float64) at ./In[128]:41
#  [5] top-level scope at ./In[129]:9

# %%
dbeta=betas[2:end]-betas[1:end-1]
dbeta=[dbeta[1]; dbeta]
dS=- Ch .* dbeta ./(betas)
S=zeros(length(betas))
for ii in 1:length(betas)
    S[ii]=sum(dS[1:ii])
end

# %%
plot(1.0 ./betas,S.+log(2) )
hline!([log(2),.431])

plot!(legend=:false)

# %% [markdown]
# ### Storing and Restoring Data
#
# Since running these simulations take slightly longer than some of my previous posts, I've outputed data files of the results of three different sizes lattices (l=10, l=20, l=50), for runs of length 100,000.  All have the same `betas` variable. Feel free to take a look at them, or make your own data :)

# %%
writedlm(string("SpinIceL",l,"t",t,".dat"),[betas Mm Mstd Ee Estd Ch χ])

# %%
temp=readdlm("SpinIceL50t100000.dat")
betas=temp[:,1];
Mm50=temp[:,2];
Mstd50=temp[:,3];
Ee50=temp[:,4];
Estd50=temp[:,5];
Ch50=temp[:,6];
χ50=temp[:,7];

temp=readdlm("SpinIceL10t100000.dat")
Mm10=temp[:,2];
Mstd10=temp[:,3];
Ee10=temp[:,4];
Estd10=temp[:,5];
Ch10=temp[:,6];
χ10=temp[:,7];

temp=readdlm("SpinIceL20t100000.dat")
Mm20=temp[:,2];
Mstd20=temp[:,3];
Ee20=temp[:,4];
Estd20=temp[:,5];
Ch20=temp[:,6];
χ20=temp[:,7];

# %% [markdown]
# # Plotting Section

# %%
plot(betas,Mm)

# %%
plot(1.0 ./betas,Ee)

# %%
plot(log10.(1.0 ./betas),Ch )

# %%
plot(log10.(1.0 ./betas),χ)

# %%
## need to calculate direction of spin
plot(log10.(1.0 ./betas),χ2D./betas)
