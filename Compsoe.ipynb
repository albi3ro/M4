# %%
using Gadfly, Compose, Colors
base03=parse(Colorant,"#002b36");
base02=parse(Colorant,"#073642");
base01=parse(Colorant,"#586e75");
base00=parse(Colorant,"#657b83");
base0=parse(Colorant,"#839496");
base1=parse(Colorant,"#839496");
base2=parse(Colorant,"#eee8d5");
base3=parse(Colorant,"#fdf6e3");

yellow=parse(Colorant,"#b58900");
orange=parse(Colorant,"#cb4b16");
red=parse(Colorant,"#dc322f");
magenta=parse(Colorant,"#d33682");
violet=parse(Colorant,"#6c71c4");
blue=parse(Colorant,"#268bd2");
cyan=parse(Colorant,"#3aa198");
green=parse(Colorant,"#859900");

# %%
x=.1:.1:.9;
y=.1:.1:.9;
w=.05*ones(y);

# %%
compose(context(),
compose(context(),ellipse(x,y,w,.5*w),fill(base3)),
compose(context(),rectangle(),fill(base03))
)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNode{Compose.Container}(Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNull{Compose.Container}(),Compose.ListNode{Compose.Form{P<:Compose.FormPrimitive}}(Compose.Form{Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}([Compose.RectanglePrimitive{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Measures.Length{:w,Float64},Measures.Length{:h,Float64}}((0.0w,0.0h),1.0w,1.0h)],symbol("")),Compose.ListNull{Compose.Form{P<:Compose.FormPrimitive}}()),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.FillPrimitive}([Compose.FillPrimitive(RGBA{Float64}(0.0,0.16862745098039217,0.21176470588235294,1.0))]),Compose.ListNull{Compose.Property{P<:Compose.PropertyPrimitive}}()),0,false,false,false,false,nothing,nothing,0.0,symbol("")),Compose.ListNode{Compose.Container}(Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNull{Compose.Container}(),Compose.ListNode{Compose.Form{P<:Compose.FormPrimitive}}(Compose.Form{Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}}([Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.1cx,0.1cy),(0.15000000000000002cx,0.1cy),(0.1cx,0.125cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.2cx,0.2cy),(0.25cx,0.2cy),(0.2cx,0.225cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.3cx,0.3cy),(0.35cx,0.3cy),(0.3cx,0.325cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.4cx,0.4cy),(0.45cx,0.4cy),(0.4cx,0.42500000000000004cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.5cx,0.5cy),(0.55cx,0.5cy),(0.5cx,0.525cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}}}((0.6cx,0.6cy),(0.65cx,0.6cy),(0.6cx,0.625cy)),Compose.EllipsePrimitive{Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{:cy,Float64}},Tuple{Measures.Length{:cx,Float64},Measures.Length{: ...

# %%
ctx=context()
compose!(ctx,line([(0.1,0.9),(0.9,0.1)]),stroke(yellow),fill(base3),linewidth(2pt)
)
compose!(ctx,line([(0.1,0.1),(0.9,0.9)]),stroke(yellow),fill(base3),linewidth(2pt)
)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}},Tuple{Measures.Length{:w,Float64},Measures.Length{:h,Float64}}}((0.0w,0.0h),(1.0w,1.0h)),Nullable{Compose.UnitBox{S,T,U,V}}(),Nullable{Compose.Rotation{P<:NTuple{N,Measures.Measure}}}(),Nullable{Compose.Mirror}(),Compose.ListNull{Compose.Container}(),Compose.ListNode{Compose.Form{P<:Compose.FormPrimitive}}(Compose.Form{Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}}([Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.1cx,0.1cy),(0.9cx,0.9cy)])],symbol("")),Compose.ListNode{Compose.Form{P<:Compose.FormPrimitive}}(Compose.Form{Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}}([Compose.LinePrimitive{Tuple{Measures.Measure,Measures.Measure}}(Tuple{Measures.Measure,Measures.Measure}[(0.1cx,0.9cy),(0.9cx,0.1cy)])],symbol("")),Compose.ListNull{Compose.Form{P<:Compose.FormPrimitive}}())),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.LineWidthPrimitive}([Compose.LineWidthPrimitive(0.7055555555555555mm)]),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.FillPrimitive}([Compose.FillPrimitive(RGBA{Float64}(0.9921568627450981,0.9647058823529412,0.8901960784313725,1.0))]),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.StrokePrimitive}([Compose.StrokePrimitive(RGBA{Float64}(0.7098039215686275,0.5372549019607843,0.0,1.0))]),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.LineWidthPrimitive}([Compose.LineWidthPrimitive(0.7055555555555555mm)]),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.FillPrimitive}([Compose.FillPrimitive(RGBA{Float64}(0.9921568627450981,0.9647058823529412,0.8901960784313725,1.0))]),Compose.ListNode{Compose.Property{P<:Compose.PropertyPrimitive}}(Compose.Property{Compose.StrokePrimitive}([Compose.StrokePrimitive(RGBA{Float64}(0.7098039215686275,0.5372549019607843,0.0,1.0))]),Compose.ListNull{Compose.Property{P<:Compose.PropertyPrimitive}}())))))),0,false,false,false,false,nothing,nothing,0.0,symbol(""))
